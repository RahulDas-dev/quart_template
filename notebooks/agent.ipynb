# %%
import logging
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "src")))

import nest_asyncio
from dotenv import load_dotenv

from configs import app_config
from service.pdf2img import Pdf2ImgService, Pdf2ImgConfig
from service.invoice.service import InvoiceService, InvoiceSeviceConfig

# %%
load_dotenv()

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    handlers=[logging.StreamHandler()],
)
nest_asyncio.apply()

# %%
POPPLER_PATH_='C:/Users/rdas6/OneDrive/Desktop/codespace/vyturr/poppler-24.08.0/Library/bin'
OUTPUT_PATH_='C:/Users/rdas6/OneDrive/Desktop/codespace/vyturr/temp/pdf2img'

print(POPPLER_PATH_)
print(OUTPUT_PATH_)

config1 = Pdf2ImgConfig(poppler_path=POPPLER_PATH_, output_path=OUTPUT_PATH_)

pdf_path = "C:/Users/rdas6/OneDrive/Desktop/codespace/vyturr/dataset/Invoice-Copy-20.pdf"

Pdf2ImgService.set_config(config1)

image_dir = Pdf2ImgService.convert(pdf_path)
print(image_dir)
# Out:
# C:/Users/rdas6/OneDrive/Desktop/codespace/vyturr/poppler-24.08.0/Library/bin
# C:/Users/rdas6/OneDrive/Desktop/codespace/vyturr/temp/pdf2img
# 2025-03-23 19:52:53,039 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:53,116 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,177 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:53,244 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,275 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:53,332 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,363 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:53,423 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,467 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:53,524 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,543 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:53,618 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,650 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:53,709 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,739 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:53,790 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,794 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:53,856 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,894 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:53,943 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:53,984 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,025 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,042 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,122 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,169 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,222 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,258 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,326 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,372 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,430 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,472 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,511 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,543 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,576 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,625 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,691 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,737 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,805 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,859 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:54,908 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:54,948 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,014 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,038 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,094 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,127 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,176 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,204 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,254 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,273 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,343 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,371 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,423 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,467 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,530 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,554 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,622 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,654 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,714 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,737 - service.pdf2img - INFO - Processing Images of shape 1653, 2339
# 2025-03-23 19:52:55,808 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,838 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:55,904 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:55,954 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:56,012 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:56,054 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:56,103 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:56,137 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:56,179 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# 2025-03-23 19:52:56,203 - service.pdf2img - INFO - Processing Images of shape 1654, 2339
# 2025-03-23 19:52:56,278 - service.pdf2img - INFO - Resized Images to shape (791, 1120)
# C:\Users\rdas6\OneDrive\Desktop\codespace\vyturr\temp\pdf2img\Invoice-Copy-20_1

# %%
image_dir ='C:/Users/rdas6/OneDrive/Desktop/codespace/vyturr/temp/pdf2img/Invoice-Copy-20'

InvoiceService.set_config(InvoiceSeviceConfig())
json_data, data_str = InvoiceService.run(image_dir)
# Out:
# 2025-03-23 19:54:42,885 - service.invoice.service - INFO - Agent1 Processing Page : Page_01.png
# 2025-03-23 19:54:55,748 - service.invoice.service - INFO - Agent1 Processing Page : Page_02.png
# 2025-03-23 19:55:03,021 - service.invoice.service - INFO - Agent1 Processing Page : Page_03.png
# 2025-03-23 19:55:10,731 - service.invoice.service - INFO - Agent1 Processing Page : Page_04.png
# 2025-03-23 19:55:17,660 - service.invoice.service - INFO - Agent1 Processing Page : Page_05.png
# 2025-03-23 19:55:25,148 - service.invoice.service - INFO - Agent1 Processing Page : Page_06.png
# 2025-03-23 19:55:35,374 - service.invoice.service - INFO - Agent1 Processing Page : Page_07.png
# 2025-03-23 19:55:43,259 - service.invoice.service - INFO - Agent1 Processing Page : Page_08.png
# 2025-03-23 19:55:44,185 - service.invoice.service - INFO - Agent1 Processing Page : Page_09.png
# 2025-03-23 19:55:50,032 - service.invoice.service - INFO - Agent1 Processing Page : Page_10.png
# 2025-03-23 19:55:56,489 - service.invoice.service - INFO - Agent1 Processing Page : Page_11.png
# 2025-03-23 19:55:57,803 - service.invoice.service - INFO - Agent1 Processing Page : Page_12.png
# 2025-03-23 19:55:59,078 - service.invoice.service - INFO - Agent1 Processing Page : Page_13.png
# 2025-03-23 19:56:04,872 - service.invoice.service - INFO - Agent1 Processing Page : Page_14.png
# 2025-03-23 19:56:07,947 - service.invoice.service - INFO - Agent1 Processing Page : Page_15.png
# 2025-03-23 19:56:14,719 - service.invoice.service - INFO - Agent1 Processing Page : Page_16.png
# 2025-03-23 19:56:21,148 - service.invoice.service - INFO - Agent1 Processing Page : Page_17.png
# 2025-03-23 19:56:26,781 - service.invoice.service - INFO - Agent1 Processing Page : Page_18.png
# 2025-03-23 19:56:33,438 - service.invoice.service - INFO - Agent1 Processing Page : Page_19.png
# 2025-03-23 19:56:39,579 - service.invoice.service - INFO - Agent1 Processing Page : Page_20.png
# 2025-03-23 19:56:45,215 - service.invoice.service - INFO - Agent1 Processing Page : Page_21.png
# 2025-03-23 19:56:51,972 - service.invoice.service - INFO - Agent1 Processing Page : Page_22.png
# 2025-03-23 19:57:03,744 - service.invoice.service - INFO - Agent1 Processing Page : Page_23.png
# 2025-03-23 19:57:10,492 - service.invoice.service - INFO - Agent1 Processing Page : Page_24.png
# 2025-03-23 19:57:17,454 - service.invoice.service - INFO - Agent1 Processing Page : Page_25.png
# 2025-03-23 19:57:27,809 - service.invoice.service - INFO - Agent1 Processing Page : Page_26.png
# 2025-03-23 19:57:37,029 - service.invoice.service - INFO - Agent1 Processing Page : Page_27.png
# 2025-03-23 19:57:43,890 - service.invoice.service - INFO - Agent1 Processing Page : Page_28.png
# 2025-03-23 19:57:51,365 - service.invoice.service - INFO - Agent1 Processing Page : Page_29.png
# 2025-03-23 19:58:01,396 - service.invoice.service - INFO - Agent1 Processing Page : Page_30.png
# 2025-03-23 19:58:08,270 - service.invoice.service - INFO - Agent1 Processing Page : Page_31.png
# 2025-03-23 19:58:22,704 - service.invoice.service - INFO - Agent1 Processing Page : Page_32.png
# 2025-03-23 19:58:36,826 - service.invoice.service - INFO - Agent1 Processing Page : Page_33.png
# 2025-03-23 19:58:51,067 - service.invoice.service - INFO - Agent1 Processing Page : Page_34.png
# 2025-03-23 19:59:01,925 - service.invoice.service - INFO - Agent1 Processing Page : Page_35.png
# 2025-03-23 19:59:09,706 - service.invoice.service - INFO - Agent1 has completed the processing of 35 pages
# 2025-03-23 19:59:09,706 - service.invoice.service - INFO - Agent2 Processing Page No : 1
# 2025-03-23 19:59:14,314 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:14,326 - service.invoice.service - INFO - Agent2 Processing Page No : 2
# 2025-03-23 19:59:17,473 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:17,589 - service.invoice.service - INFO - Agent2 Processing Page No : 3
# 2025-03-23 19:59:20,149 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:20,154 - service.invoice.service - INFO - Agent2 Processing Page No : 4
# 2025-03-23 19:59:22,499 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:22,509 - service.invoice.service - INFO - Agent2 Processing Page No : 5
# 2025-03-23 19:59:25,163 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:25,166 - service.invoice.service - INFO - Agent2 Processing Page No : 6
# 2025-03-23 19:59:28,854 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:28,859 - service.invoice.service - INFO - Agent2 Processing Page No : 7
# 2025-03-23 19:59:31,002 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:31,004 - service.invoice.service - INFO - Agent2 Processing Page No : 8
# 2025-03-23 19:59:31,810 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:31,826 - service.invoice.service - INFO - Agent2 Processing Page No : 9
# 2025-03-23 19:59:33,766 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:33,766 - service.invoice.service - INFO - Agent2 Processing Page No : 10
# 2025-03-23 19:59:35,418 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:35,418 - service.invoice.service - INFO - Agent2 Processing Page No : 11
# 2025-03-23 19:59:36,331 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:36,331 - service.invoice.service - INFO - Agent2 Processing Page No : 12
# 2025-03-23 19:59:37,141 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:37,154 - service.invoice.service - INFO - Agent2 Processing Page No : 13
# 2025-03-23 19:59:39,098 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:39,101 - service.invoice.service - INFO - Agent2 Processing Page No : 14
# 2025-03-23 19:59:41,032 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:41,032 - service.invoice.service - INFO - Agent2 Processing Page No : 15
# 2025-03-23 19:59:43,080 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:43,089 - service.invoice.service - INFO - Agent2 Processing Page No : 16
# 2025-03-23 19:59:44,813 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:44,831 - service.invoice.service - INFO - Agent2 Processing Page No : 17
# 2025-03-23 19:59:46,148 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:46,163 - service.invoice.service - INFO - Agent2 Processing Page No : 18
# 2025-03-23 19:59:47,871 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:47,877 - service.invoice.service - INFO - Agent2 Processing Page No : 19
# 2025-03-23 19:59:49,025 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:49,036 - service.invoice.service - INFO - Agent2 Processing Page No : 20
# 2025-03-23 19:59:50,152 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:50,152 - service.invoice.service - INFO - Agent2 Processing Page No : 21
# 2025-03-23 19:59:51,999 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:51,999 - service.invoice.service - INFO - Agent2 Processing Page No : 22
# 2025-03-23 19:59:55,571 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:55,588 - service.invoice.service - INFO - Agent2 Processing Page No : 23
# 2025-03-23 19:59:57,826 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 19:59:57,834 - service.invoice.service - INFO - Agent2 Processing Page No : 24
# 2025-03-23 20:00:00,189 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:00,193 - service.invoice.service - INFO - Agent2 Processing Page No : 25
# 2025-03-23 20:00:03,050 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:03,055 - service.invoice.service - INFO - Agent2 Processing Page No : 26
# 2025-03-23 20:00:04,998 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:05,001 - service.invoice.service - INFO - Agent2 Processing Page No : 27
# 2025-03-23 20:00:07,042 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:07,049 - service.invoice.service - INFO - Agent2 Processing Page No : 28
# 2025-03-23 20:00:09,707 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:09,715 - service.invoice.service - INFO - Agent2 Processing Page No : 29
# 2025-03-23 20:00:11,874 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:11,894 - service.invoice.service - INFO - Agent2 Processing Page No : 30
# 2025-03-23 20:00:14,214 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:14,221 - service.invoice.service - INFO - Agent2 Processing Page No : 31
# 2025-03-23 20:00:18,610 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:18,619 - service.invoice.service - INFO - Agent2 Processing Page No : 32
# 2025-03-23 20:00:22,714 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:22,718 - service.invoice.service - INFO - Agent2 Processing Page No : 33
# 2025-03-23 20:00:27,111 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:27,123 - service.invoice.service - INFO - Agent2 Processing Page No : 34
# 2025-03-23 20:00:29,981 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-23 20:00:29,991 - service.invoice.service - INFO - Agent2 Processing Page No : 35
# 2025-03-23 20:00:31,947 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ({'details': [{'invoice_number': 'Trans_BL_004',
#     'invoice_date': '08/04/2021',
#     'seller_details': {'name': 'Transitech Private Limited',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Regd. & Corp. Office: Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai - 600 058. Tamilnadu, India.',
#      'phone_number': '+91-44-4203 1951',
#      'email': 'info@transitech.in'},
#     'buyer_details': {'name': 'Billionloans Financial Services Pvt Ltd',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '370, 4th Cross, J P Nagar III Phase, Bangalore 560 078 India',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'UPS SCS (India) Pvt Ltd',
#       'quantity': '20 FEET',
#       'price': '27000.00',
#       'currency': 'Not Available'},
#      {'slno': 2,
#       'description': 'UPS SCS (India) Pvt Ltd',
#       'quantity': '20 FEET',
#       'price': '27000.00',
#       'currency': 'Not Available'},
#      {'slno': 3,
#       'description': 'UPS SCS (India) Pvt Ltd',
#       'quantity': '20 FEET',
#       'price': '27000.00',
#       'currency': 'Not Available'},
#      {'slno': 4,
#       'description': 'UPS SCS (India) Pvt Ltd',
#       'quantity': '16 Ton',
#       'price': '19200.00',
#       'currency': 'Not Available'},
#      {'slno': 5,
#       'description': 'UPS SCS (India) Pvt Ltd',
#       'quantity': '16 Ton',
#       'price': '19200.00',
#       'currency': 'Not Available'},
#      {'slno': 6,
#       'description': 'UPS SCS (India) Pvt Ltd',
#       'quantity': '16 Ton',
#       'price': '19200.00',
#       'currency': 'Not Available'},
#      {'slno': 7,
#       'description': 'UPS SCS (India) Pvt Ltd',
#       'quantity': '16 Ton',
#       'price': '19200.00',
#       'currency': 'Not Available'},
#      {'slno': 8,
#       'description': 'UPS SCS (India) Pvt Ltd',
#       'quantity': '16 Ton',
#       'price': '19200.00',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 177000.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 1},
#    {'invoice_number': '20212500',
#     'invoice_date': '3/23/2021 12:00:00 AM',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '+91-7550015666,8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'Ms. SHARADAA CERAMICS PRIVATE LIMITED DP',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '39 4B 5B KAKKALUR INDUSTRIAL ESTATE KAKKALUR THIRUVALLUR-602003',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'SB NO 96085 40/24.03.21 CNTR NO. FCIU4299693',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 2},
#    {'invoice_number': '20-21/2500',
#     'invoice_date': '23-3-2021',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '7550015666 / 8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD',
#      'gst_no': '33AAACU2488B1ZN',
#      'pan_no': 'Not Available',
#      'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Your Freight Driver was Sathish',
#       'quantity': '1',
#       'price': '17000.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 27000.0,
#     'total_discount': 0.0,
#     'total_amount': 27000.0,
#     'amount_paid': 27000.0,
#     'amount_due': 0.0,
#     'page_no': 3},
#    {'invoice_number': '20-21/2498',
#     'invoice_date': '23-3-2021',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '7550015666 / 8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD',
#      'gst_no': '33AAACU2488B1ZN',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'SB NO 9608540 / 24.03.21 / CNTR : MEDU6312755',
#       'quantity': '1',
#       'price': '27000.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 27000.0,
#     'amount_paid': 27000.0,
#     'amount_due': 0.0,
#     'page_no': 4},
#    {'invoice_number': '20212498',
#     'invoice_date': '3/23/2021 12:00:00 AM',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFC T5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '+91-7550015666,8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'Ms. SHARADAA CERAMICS PRIVATE LIMITED DP',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '39 4B 5B KAKKALUR INDUSTRIAL ESTATE KAKKALUR THIRUVALLUR-602003',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'SB NO 9608540 / 24.03.21 / CNTR : MEDU6312755',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 5},
#    {'invoice_number': '20-21/2499',
#     'invoice_date': '23-3-2021',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '7550015666 / 8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD',
#      'gst_no': '33AAACU2488B1ZN',
#      'pan_no': 'Not Available',
#      'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Your Freight Driver was Sundar',
#       'quantity': '1',
#       'price': 'Rs.17000.00',
#       'currency': 'INR'},
#      {'slno': 2,
#       'description': 'Distance Fare',
#       'quantity': '1',
#       'price': 'Rs.10000.00',
#       'currency': 'INR'},
#      {'slno': 3,
#       'description': 'Halting Charges',
#       'quantity': '1',
#       'price': 'Rs.0.00',
#       'currency': 'INR'},
#      {'slno': 4,
#       'description': 'Loading Charges',
#       'quantity': '1',
#       'price': 'Rs.0.00',
#       'currency': 'INR'},
#      {'slno': 5,
#       'description': 'Unloading Charges',
#       'quantity': '1',
#       'price': 'Rs.0.00',
#       'currency': 'INR'},
#      {'slno': 6,
#       'description': 'Extra Delivery Charges',
#       'quantity': '1',
#       'price': 'Rs.0.00',
#       'currency': 'INR'},
#      {'slno': 7,
#       'description': 'Additional Point Charges',
#       'quantity': '1',
#       'price': 'Rs.0.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 27000.0,
#     'total_discount': 0.0,
#     'total_amount': 27000.0,
#     'amount_paid': 27000.0,
#     'amount_due': 0.0,
#     'page_no': 6},
#    {'invoice_number': '20212499',
#     'invoice_date': '3/23/2021 12:00:00 AM',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFC T5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '+91-7550015666,8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'Ms. SHARADAA CERAMICS PRIVATE LIMITED DP',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '39 4B 5B KAKKALUR INDUSTRIAL ESTATE KAKKALUR THIRUVALLUR-602003',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Actual Kgs',
#       'quantity': '1',
#       'price': 'SB NO. 9608540 /24.03.21 CNTR NO. FCIU3397714',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 7},
#    {'invoice_number': 'Not Available',
#     'invoice_date': 'Not Available',
#     'seller_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 8},
#    {'invoice_number': '5512 4954 4247',
#     'invoice_date': '16/03/2021',
#     'seller_details': {'name': 'SALZER EXPORTS LIMITED',
#      'gst_no': '33AADCS0675B1ZT',
#      'pan_no': 'Not Available',
#      'address': 'TAMIL NADU-641047',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065H2Z7',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'CONDUIT TUBING',
#       'quantity': '1',
#       'price': '58968.1',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 58968.1,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 9},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '3/28/21 4:00 AM',
#     'seller_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Not Available',
#       'quantity': 'Not Available',
#       'price': 'Not Available',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 10},
#    {'invoice_number': 'NO_INVOICE',
#     'invoice_date': 'Not Available',
#     'seller_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 11},
#    {'invoice_number': 'NO_INVOICE',
#     'invoice_date': 'Not Available',
#     'seller_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 12},
#    {'invoice_number': '0016084',
#     'invoice_date': '25/03/2021',
#     'seller_details': {'name': 'SRI JAYARAM COMPUTER WEIGH BRIDGE',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'No. 27 to 30-A, M.T.H. Road, Kakkalur, Thiruvallur - 602 003.',
#      'phone_number': '2766 6529',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'CONTAINER',
#       'quantity': '42',
#       'price': '120.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 120.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 13},
#    {'invoice_number': 'NO_INVOICE',
#     'invoice_date': 'Not Available',
#     'seller_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 14},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '27/03/2021',
#     'seller_details': {'name': 'SCOTT BROTHERS ENTERPRISES LTD',
#      'gst_no': 'NOT_AVAILABLE',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'BANKWELL ROAD, BANKWELL BUSINESS PARK, KAKALOOR, THIRUVELLORE DISTRICT, TAMIL NADU, UNITED KINGDOM',
#      'phone_number': 'NOT_AVAILABLE',
#      'email': 'NOT_AVAILABLE'},
#     'buyer_details': {'name': 'SHARADAA CERAMICS PRIVATE LIMITED',
#      'gst_no': 'NOT_AVAILABLE',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'D-39, 4B KAKALOOR INDUSTRIAL ESTATE, UNIT 1, BANKWELL BUSINESS PARK, KAKALOOR, THIRUVELLORE DISTRICT, TAMIL NADU',
#      'phone_number': 'NOT_AVAILABLE',
#      'email': 'NOT_AVAILABLE'},
#     'items': [{'slno': 1,
#       'description': 'NOT_AVAILABLE',
#       'quantity': '60',
#       'price': '0.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 15},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '27/03/2021',
#     'seller_details': {'name': 'SCOTT BROTHERS ENTERPRISES LTD',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'UNIT A BANKWELL BUSINESS PARK BANKWELL ROAD MELKSHAM BRIDGE MUDERSFIELD, HD3 4LU UNITED KINGDOM',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'SHAOJAI CERAMICS PRIVATE LIMITED',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '0:39, 40 KAKALDOR INDUSTRIAL ESTATE, CHENNAI - 600601',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Not Available',
#       'quantity': '60',
#       'price': '78000.000',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 1170.0,
#     'total_discount': 0.0,
#     'total_amount': 79170.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 16},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '15/03/2021',
#     'seller_details': {'name': 'SHARADAA CERAMICS PRIVATE LIMITED',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'SCOTT BROTHERS ENTERPRISES LTD',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'LUMINA REFRACTORY CEMENT AND MORTO',
#       'quantity': '35.44',
#       'price': '35.44',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 71.6,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 17},
#    {'invoice_number': '9608540',
#     'invoice_date': '24/03/2021',
#     'seller_details': {'name': 'CUSTOMS HOUSE G.O. RAJAJISALAI, CHENNAI-600001',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'CUSTOMS HOUSE G.O. RAJAJISALAI, CHENNAI-600001',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'AALCHIDRSECHBBI TRANSDREIN LOGISTICS SERVICES PVT LTD',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'E SINGLE WINDOW INFO TYPE DETAILS F',
#       'quantity': '1.00',
#       'price': '78000.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 78000.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 18},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '24/03/2021',
#     'seller_details': {'name': 'TRANSORION LOGISTICS SERVICES PVT LTD',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'SHARADAA CERAMICS PRIVATE LIMITED',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'KAKALOOR INDUSTRIAL ESTATE, KAKALOOR, THIRUVELLORE DISTRICT, TAMIL NADU',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 19},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '27/03/2021',
#     'seller_details': {'name': 'CALYX CONTAINER TERMINALS PVT. LTD. CFS',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Puzhal, Chennai - 600 066',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'Not Available',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'Not Available',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 20},
#    {'invoice_number': '20-21/2389',
#     'invoice_date': '16-3-2021',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '7550015666 / 8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD',
#      'gst_no': '33AAACU2488B1ZN',
#      'pan_no': 'Not Available',
#      'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Dharmalingam',
#       'quantity': '500 Km',
#       'price': '19200.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 19200.0,
#     'total_discount': 0.0,
#     'total_amount': 19200.0,
#     'amount_paid': 19200.0,
#     'amount_due': 0.0,
#     'page_no': 21},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '3/16/2021 12:00:00 AM',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAT5065J1Z7',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '+91-7550015666,8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'Salzer Exports Ltd',
#      'gst_no': 'NOT_AVAILABLE',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': '9/175A, Railway Feeder Road, Perianaickenpalayam, Coimbatore 641020',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Actual Kgs',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 2,
#       'description': 'Paid',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 3,
#       'description': 'Rate',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 4,
#       'description': 'Rs',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 5,
#       'description': 'P',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 6,
#       'description': 'Charged Kgs',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 7,
#       'description': 'Hamali',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 8,
#       'description': 'Door Collection',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 9,
#       'description': 'Pvt. Marking',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 10,
#       'description': 'Door Delivery',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 11,
#       'description': 'Surcharge',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'},
#      {'slno': 12,
#       'description': 'St.Charge',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 22},
#    {'invoice_number': '20-21/2390',
#     'invoice_date': '16-3-2021',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '7550015666 / 8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD',
#      'gst_no': '33AAACU2488B1ZN',
#      'pan_no': 'Not Available',
#      'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Your Freight Driver was',
#       'quantity': '1',
#       'price': '19200.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 19200.0,
#     'amount_paid': 19200.0,
#     'amount_due': 0.0,
#     'page_no': 23},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '3/16/2021 12:00:00 AM',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '+91-7550015666,8939601566',
#      'email': 'support@freightxin'},
#     'buyer_details': {'name': 'SALZAR EXPORTS LTD',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '9/175A, Railway Feeder Road, Perianaickenpalayam, Coimbatore 641020',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Actual Kgs',
#       'quantity': '1',
#       'price': 'SB NO 9418939 / 17.03.21',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 24},
#    {'invoice_number': '20-21/2391',
#     'invoice_date': '16-3-2021',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '7550015666 / 8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD',
#      'gst_no': '33AAACU2488B1ZN',
#      'pan_no': 'Not Available',
#      'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Your Freight Driver was',
#       'quantity': '1',
#       'price': '19200.00',
#       'currency': 'INR'},
#      {'slno': 2,
#       'description': 'Total Distance',
#       'quantity': '500 Km',
#       'price': '0.00',
#       'currency': 'INR'},
#      {'slno': 3,
#       'description': 'Waiting Minutes',
#       'quantity': '0 mins',
#       'price': '0.00',
#       'currency': 'INR'},
#      {'slno': 4,
#       'description': 'Total Trip Time',
#       'quantity': '0',
#       'price': '0.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 19200.0,
#     'amount_paid': 19200.0,
#     'amount_due': 0.0,
#     'page_no': 25},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '3/16/2021 12:00:00 AM',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '+91-7550015666,8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'SALZER EXPORTS LTD',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '9/175A Railway Feeder Road, Perianaickenpalayam, Coimbatore 641 020',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Actual Kgs',
#       'quantity': '1',
#       'price': 'SB NO 9421512/17.03.21',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 26},
#    {'invoice_number': '20-21/2393',
#     'invoice_date': '16-3-2021',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '7550015666 / 8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD',
#      'gst_no': '33AAACU2488B1ZN',
#      'pan_no': 'Not Available',
#      'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Your Freightx Driver was',
#       'quantity': '1.000',
#       'price': '19200.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 19200.0,
#     'amount_paid': 19200.0,
#     'amount_due': 0.0,
#     'page_no': 27},
#    {'invoice_number': '20212393',
#     'invoice_date': '3/16/2021 12:00:00 AM',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '+91-7550015666,8939601566',
#      'email': 'support@freightxin'},
#     'buyer_details': {'name': 'SALZAR Exports Ltd',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '9/175A, Railway Feeder Road, Perianaickenpalayam, Coimbatore 641020',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Actual Kgs',
#       'quantity': '1',
#       'price': 'Rs P',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 28},
#    {'invoice_number': '20-21/2394',
#     'invoice_date': '16-3-2021',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '7550015666 / 8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD',
#      'gst_no': '33AAACU2488B1ZN',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'Your Freightx Driver was',
#       'quantity': '1',
#       'price': 'Rs.19200.00',
#       'currency': 'INR'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 19200.0,
#     'amount_paid': 19200.0,
#     'amount_due': 0.0,
#     'page_no': 29},
#    {'invoice_number': 'NOT_AVAILABLE',
#     'invoice_date': '3/16/2021 12:00:00 AM',
#     'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED',
#      'gst_no': '33AAFCT5065J1Z7',
#      'pan_no': 'Not Available',
#      'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058',
#      'phone_number': '+91-7550015666,8939601566',
#      'email': 'support@freightx.in'},
#     'buyer_details': {'name': 'SALZER EXPORTS LTD',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '9/175A, Railway Feeder Road, Periannaickenpalayam, Coimbatore 641020',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'SB 9418926/17.03.21',
#       'quantity': '1',
#       'price': 'Not Available',
#       'currency': 'Not Available'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 0.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 30},
#    {'invoice_number': 'T003337/2021',
#     'invoice_date': '15-03-2021',
#     'seller_details': {'name': 'TRANSORION LOGISTICS SERVICES PVT LTD',
#      'gst_no': '33AADC5067SB1ZT',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'CONTROL CONCEPTS CORPORATION DBA C3 CONTROLS P.O BOX NO 496 BEAVER PENNSYLVANIA USA 15009 EIN 25-1309760 US (UNITED STATES OF AMERICA)',
#      'phone_number': 'NOT_AVAILABLE',
#      'email': 'NOT_AVAILABLE'},
#     'buyer_details': {'name': 'CONTROL CONCEPTS CORPORATION DBA C3 CONTROLS 658 STATE AVE VANDORT PA 15009 USA',
#      'gst_no': 'NOT_AVAILABLE',
#      'pan_no': 'NOT_AVAILABLE',
#      'address': 'CONTROL CONCEPTS CORPORATION DBA C3 CONTROLS 658 STATE AVE VANDORT PA 15009 USA',
#      'phone_number': 'NOT_AVAILABLE',
#      'email': 'NOT_AVAILABLE'},
#     'items': [{'slno': 1,
#       'description': 'RTC',
#       'quantity': '150',
#       'price': '6.61',
#       'currency': 'USD'},
#      {'slno': 2,
#       'description': 'LB-1/2 TO 2/2 LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES (NOS) 32A LB232 31309 MB35 RD Y/R (PDS2-3205P)',
#       'quantity': '250',
#       'price': '6.91',
#       'currency': 'USD'},
#      {'slno': 3,
#       'description': 'LB-1/2 TO 2/2 LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES (NOS) 63A LB263 31309 MB35 RD Y/R (PDS2-3605P)',
#       'quantity': '50',
#       'price': '0.54',
#       'currency': 'USD'},
#      {'slno': 4,
#       'description': 'LB-1/2 TO 2/2 LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES (NOS) 25A LB225 31309 MB35 RD Y/R (PDS2-3255P)',
#       'quantity': '50',
#       'price': '6.19',
#       'currency': 'USD'},
#      {'slno': 5,
#       'description': 'LB-1/2 TO 2/2 LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES (NOS) 40A LB240 31309 MB35 RD Y/R (PDS2-3405P)',
#       'quantity': '50',
#       'price': '6.44',
#       'currency': 'USD'},
#      {'slno': 6,
#       'description': 'LB-1/2 TO 2/2 LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES (NOS) 63A LB263 31309 MB35 Y/R (PDS2-3605P)',
#       'quantity': '50',
#       'price': '6.91',
#       'currency': 'USD'},
#      {'slno': 7,
#       'description': 'LB-1/2 TO 2/2 LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES (NOS) 63A LB263 31309 MB35 Y/R (PDS2-3605P)',
#       'quantity': '50',
#       'price': '6.91',
#       'currency': 'USD'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 3602.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 31},
#    {'invoice_number': '6480016',
#     'invoice_date': '15-03-2021',
#     'seller_details': {'name': 'TRANSORION LOGISTICS SERVICES PVT LTD',
#      'gst_no': '33AADCS0675B1ZT',
#      'pan_no': 'Not Available',
#      'address': 'TRANSORION LOGISTICS SERVICES PVT LTD, 1B, CONTROLS P O BOX NO 41456, PRAYER PENNSYLVANIA USA 15009',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'CONTROL CONCEPTS CORPORATION DBA',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'C3 CONTROLS 656 STATE AVE, VANPORT, PA 15009 USA',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'BRAND:C3 LB-1/6TO 6/6:LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES(NOS) 25A LB225 31309 B33 RD Y/R (DDS2-32)',
#       'quantity': '1',
#       'price': '2230.00000',
#       'currency': 'USD'},
#      {'slno': 2,
#       'description': 'BRAND:C3 LB-1/6TO 6/6:LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES(NOS) 32A LB232 31309 B33 RD Y/R (DDS2-330)',
#       'quantity': '1',
#       'price': '934.00000',
#       'currency': 'USD'},
#      {'slno': 3,
#       'description': 'BRAND:C3 LB-1/6TO 6/6:LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES(NOS) 63A LB263 31309 B33 RD Y/R (DDS2-360)',
#       'quantity': '1',
#       'price': '565.00000',
#       'currency': 'USD'},
#      {'slno': 4,
#       'description': 'BRAND:C3 LB-1/6TO 6/6:LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES(NOS) KIT APPLICABLE FOR 25<32A (EDS2-ABSENZ-)',
#       'quantity': '1',
#       'price': '225.00000',
#       'currency': 'USD'},
#      {'slno': 5,
#       'description': 'BRAND:C3 LB-1/6TO 6/6:LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES(NOS) 63A LB263 31309 B33 RD Y/R (DDS2-360)',
#       'quantity': '1',
#       'price': '565.00000',
#       'currency': 'USD'},
#      {'slno': 6,
#       'description': 'BRAND:C3 LB-1/6TO 6/6:LOAD BREAK SWITCHES & PARTS OF LOAD BREAK SWITCHES(NOS) M834 DOOR INTERLOCK SB B/B (SFBN)',
#       'quantity': '1',
#       'price': '818.00000',
#       'currency': 'USD'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 8167.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 32},
#    {'invoice_number': '200334/2021',
#     'invoice_date': '15-03-2021',
#     'seller_details': {'name': 'CONTROL CONCEPTS CORPORATION DBA',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'C3 CONTROLS 658 STATE AVE VANPORT PA 15009 USA',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'CONTROL CONCEPTS CORPORATION DBA',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'C3 CONTROLS 658 STATE AVE VANPORT PA 15009 USA',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'IRAND:C3 CD-1/10 TO 10/10 CONDUIT FITTINGS & PARTS OF CONDUIT FITTINGS (NOS) 79-0034A-B25X60 (WXH) 464MM STD SLOT IBACC 43836',
#       'quantity': '1.000',
#       'price': '39854.40000',
#       'currency': 'USD'},
#      {'slno': 2,
#       'description': 'IRAND:C3 CD-1/10 TO 10/10 CONDUIT FITTINGS & PARTS OF CONDUIT FITTINGS (NOS) 79-0107 B25X080 (WXH) 381MM STD SLOT IBACC1000 NO 42090',
#       'quantity': '1.000',
#       'price': '38266.00000',
#       'currency': 'USD'},
#      {'slno': 3,
#       'description': 'IRAND:C3 CD-1/10 TO 10/10 CONDUIT FITTINGS & PARTS OF CONDUIT FITTINGS (NOS) B25X100 (WXH) 305MM STD SLOT IBACC GREY 79-1080 9730',
#       'quantity': '1.000',
#       'price': '8844.50000',
#       'currency': 'USD'},
#      {'slno': 4,
#       'description': 'IRAND:C3 CD-1/10 TO 10/10 CONDUIT FITTINGS & PARTS OF CONDUIT FITTINGS (NOS) 79-1080 B25X100 (WXH) 305MM STD SLOT IBACC1050 40866',
#       'quantity': '1.000',
#       'price': '37146.80000',
#       'currency': 'USD'},
#      {'slno': 5,
#       'description': 'IRAND:C3 CD-1/10 TO 10/10 CONDUIT FITTINGS & PARTS OF CONDUIT FITTINGS (NOS) 79-1085 B25X100 (WXH) 279MM STD SLOT IBAC 5000NO 107270',
#       'quantity': '1.000',
#       'price': '97470.00000',
#       'currency': 'USD'},
#      {'slno': 6,
#       'description': 'IRAND:C3 CD-1/10 TO 10/10 CONDUIT FITTINGS & PARTS OF CONDUIT FITTINGS (NOS) 79-1086 B25X100 (WXH) 356MM STD SLOT IBAC 1800 NO 81486',
#       'quantity': '1.000',
#       'price': '74077.20000',
#       'currency': 'USD'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 2629.0,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 33},
#    {'invoice_number': '15-03-2021',
#     'invoice_date': '15-03-2021',
#     'seller_details': {'name': 'TRANSORION LOGISTICS SERVICES PVT LTD',
#      'gst_no': '33AADCS0675B1ZT',
#      'pan_no': 'Not Available',
#      'address': 'BEAVER PENNSYLVANIA USA 15009',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'CONTROL CONCEPTS CORPORATION DBA C3 CONTROLS P O BOX NO 496',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': 'BEAVER PENNSYLVANIA USA 15009',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'As Per Tariff : 557.82',
#       'quantity': '0.45',
#       'price': '607.50000',
#       'currency': 'USD'},
#      {'slno': 2,
#       'description': 'As Per Tariff : 61.98',
#       'quantity': '0.45',
#       'price': '67.50000',
#       'currency': 'USD'},
#      {'slno': 3,
#       'description': 'As Per Tariff : 268.58',
#       'quantity': '0.53',
#       'price': '344.50000',
#       'currency': 'USD'},
#      {'slno': 4,
#       'description': 'As Per Tariff : 557.82',
#       'quantity': '0.53',
#       'price': '715.50000',
#       'currency': 'USD'},
#      {'slno': 5,
#       'description': 'As Per Tariff : 38.0144',
#       'quantity': '3.8',
#       'price': '349.60000',
#       'currency': 'USD'},
#      {'slno': 6,
#       'description': 'As Per Tariff : 581.7856',
#       'quantity': '3.8',
#       'price': '5350.40000',
#       'currency': 'USD'},
#      {'slno': 7,
#       'description': 'As Per Tariff : 15/15 CONDUIT FITTINGS (NOS) B25X120 (KGS) 1118MM STD SLOT IBACO GR 1408 NOS OF 1118 MM LENG (79-1084)',
#       'quantity': '301.8',
#       'price': '4734.4',
#       'currency': 'USD'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 43861.5,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 34},
#    {'invoice_number': 'T003397/2021',
#     'invoice_date': '15-03-2021',
#     'seller_details': {'name': 'TRANSORION LOGISTICS SERVICES PVT LTD',
#      'gst_no': '33AADCS0675B1ZT',
#      'pan_no': 'Not Available',
#      'address': '9/117SA RAILWAY FEEDER ROAD, PERIANA ICKENPALAYAM COIMBATORE, TAMIL NADU-641020',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'buyer_details': {'name': 'CONTROL CONCEPTS CORPORATION DBA C3 CONTROLS P.O BOX 436 BEAVER PENNSYLVANIA USA 15009',
#      'gst_no': 'Not Available',
#      'pan_no': 'Not Available',
#      'address': '658 STATE AVE EXPORT, PA 15009 USA',
#      'phone_number': 'Not Available',
#      'email': 'Not Available'},
#     'items': [{'slno': 1,
#       'description': 'BRAND:C3 OR-1/5 TO 5/5 OVER LOAD RELAY (NOS) BOL RELAY1 CLASS 10 RANGE 11-17A (320-B1017)',
#       'quantity': '8',
#       'price': '67.92000',
#       'currency': 'USD'}],
#     'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#     'total_charge': 0.0,
#     'total_discount': 0.0,
#     'total_amount': 4903.824,
#     'amount_paid': 0.0,
#     'amount_due': 0.0,
#     'page_no': 35}]},
#  '\n                        Page No 1\n1. Invoice Number: Trans_BL_004\n2. Invoice Date: 08/04/2021\n3. Seller Details:\n   - Company Name: Transitech Private Limited\n   - GST No: 33AAFCT5065J1Z7\n   - PAN No: NOT_AVAILABLE\n   - Address: Regd. & Corp. Office: Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai - 600 058. Tamilnadu, India.\n   - Phone Number: +91-44-4203 1951\n   - Email: info@transitech.in\n4. Buyer Details:\n   - Company Name: Billionloans Financial Services Pvt Ltd\n   - GST No: NOT_AVAILABLE\n   - PAN No: NOT_AVAILABLE\n   - Address: 370, 4th Cross, J P Nagar III Phase, Bangalore 560 078 India\n   - Phone Number: NOT_AVAILABLE\n   - Email: NOT_AVAILABLE\n5. Item Details:\n   - 1. Description: UPS SCS (India) Pvt Ltd, Quantity: 20 FEET, Price: 27000.00, Currency: NOT_AVAILABLE\n   - 2. Description: UPS SCS (India) Pvt Ltd, Quantity: 20 FEET, Price: 27000.00, Currency: NOT_AVAILABLE\n   - 3. Description: UPS SCS (India) Pvt Ltd, Quantity: 20 FEET, Price: 27000.00, Currency: NOT_AVAILABLE\n   - 4. Description: UPS SCS (India) Pvt Ltd, Quantity: 16 Ton, Price: 19200.00, Currency: NOT_AVAILABLE\n   - 5. Description: UPS SCS (India) Pvt Ltd, Quantity: 16 Ton, Price: 19200.00, Currency: NOT_AVAILABLE\n   - 6. Description: UPS SCS (India) Pvt Ltd, Quantity: 16 Ton, Price: 19200.00, Currency: NOT_AVAILABLE\n   - 7. Description: UPS SCS (India) Pvt Ltd, Quantity: 16 Ton, Price: 19200.00, Currency: NOT_AVAILABLE\n   - 8. Description: UPS SCS (India) Pvt Ltd, Quantity: 16 Ton, Price: 19200.00, Currency: NOT_AVAILABLE\n6. Total Tax: NOT_AVAILABLE\n7. Total Charges: NOT_AVAILABLE\n8. Total Discount: NOT_AVAILABLE\n9. Total Amount: 177000.00\n10. Amount Paid: NOT_AVAILABLE\n11. Amount Due: NOT_AVAILABLE\n\n\n                        Page No 2\n1. Invoice Number: 20212500\n2. Invoice Date: 3/23/2021 12:00:00 AM\n3. Seller Details:\n   - Company Name: TRANSITECH PRIVATE LIMITED\n   - GST No: 33AAFCT5065J1Z7\n   - PAN No: NOT_AVAILABLE\n   - Address: Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058\n   - Phone Number: +91-7550015666,8939601566\n   - Email: support@freightx.in\n4. Buyer Details:\n   - Company Name: Ms. SHARADAA CERAMICS PRIVATE LIMITED DP\n   - GST No: NOT_AVAILABLE\n   - PAN No: NOT_AVAILABLE\n   - Address: 39 4B 5B KAKKALUR INDUSTRIAL ESTATE KAKKALUR THIRUVALLUR-602003\n   - Phone Number: NOT_AVAILABLE\n   - Email: NOT_AVAILABLE\n5. Item Details:\n   - 1. Description: SB NO 96085 40/24.03.21 CNTR NO. FCIU4299693, Quantity: 1, Price: NOT_AVAILABLE, Currency: NOT_AVAILABLE\n6. Total Tax:\n   - CGST: NOT_AVAILABLE\n   - SGST: NOT_AVAILABLE\n   - IGST: NOT_AVAILABLE\n7. Total Charges: NOT_AVAILABLE\n8. Total Discount: NOT_AVAILABLE\n9. Total Amount: NOT_AVAILABLE\n10. Amount Paid: NOT_AVAILABLE\n11. Amount Due: NOT_AVAILABLE\n\n\n                        Page No 3\n**Invoice Details**\n\n1. **Invoice Number**: 20-21/2500\n2. **Invoice Date**: 23-3-2021\n3. **Seller Details**:\n\t* **Company Name**: TRANSITECH PRIVATE LIMITED\n\t* **GST No**: 33AAFCT5065J1Z7\n\t* **PAN No**: NOT_AVAILABLE\n\t* **Address**: Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058\n\t* **Phone Number**: 7550015666 / 8939601566\n\t* **Email**: support@freightx.in\n4. **Buyer Details**:\n\t* **Company Name**: UPS SCS (INDIA) PVT LTD\n\t* **GST No**: 33AAACU2488B1ZN\n\t* **PAN No**: NOT_AVAILABLE\n\t* **Address**: No. 3/26, 10th Avenue, Ashok Nagar, Chennai\n\t* **Phone Number**: NOT_AVAILABLE\n\t* **Email**: NOT_AVAILABLE\n5. **Item Details**:\n\t* **Description**: Your Freight Driver was Sathish\n\t* **Quantity**: 1\n\t* **Price**: Rs. 17000.00\n\t* **Currency**: INR\n6. **Total Tax**:\n\t* **CGST**: Rs. 0.00\n\t* **SGST**: Rs. 0.00\n\t* **IGST**: Rs. 0.00\n7. **Total Charges**: Rs. 27000.00\n8. **Total Discount**: NOT_AVAILABLE\n9. **Total Amount**: Rs. 27000.00\n10. **Amount Paid**: Rs. 27000.00\n11. **Amount Due**: Rs. 0.00\n\n\n         ...

# %%
print(json_data)
# Out:
# {'details': [{'invoice_number': 'Trans_BL_004', 'invoice_date': '08/04/2021', 'seller_details': {'name': 'Transitech Private Limited', 'gst_no': '33AAFCT5065J1Z7', 'pan_no': 'Not Available', 'address': 'Regd. & Corp. Office: Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai - 600 058. Tamilnadu, India.', 'phone_number': '+91-44-4203 1951', 'email': 'info@transitech.in'}, 'buyer_details': {'name': 'Billionloans Financial Services Pvt Ltd', 'gst_no': 'Not Available', 'pan_no': 'Not Available', 'address': '370, 4th Cross, J P Nagar, III Phase, Bangalore 560 078, India', 'phone_number': 'Not Available', 'email': 'Not Available'}, 'items': [{'slno': 1, 'description': 'UPS SCS (India) Pvt Ltd', 'quantity': '20 FEET', 'price': '27000.00', 'currency': 'INR'}, {'slno': 2, 'description': 'UPS SCS (India) Pvt Ltd', 'quantity': '20 FEET', 'price': '27000.00', 'currency': 'INR'}, {'slno': 3, 'description': 'UPS SCS (India) Pvt Ltd', 'quantity': '20 FEET', 'price': '27000.00', 'currency': 'INR'}, {'slno': 4, 'description': 'UPS SCS (India) Pvt Ltd', 'quantity': '16 Ton', 'price': '19200.00', 'currency': 'INR'}, {'slno': 5, 'description': 'UPS SCS (India) Pvt Ltd', 'quantity': '16 Ton', 'price': '19200.00', 'currency': 'INR'}, {'slno': 6, 'description': 'UPS SCS (India) Pvt Ltd', 'quantity': '16 Ton', 'price': '19200.00', 'currency': 'INR'}, {'slno': 7, 'description': 'UPS SCS (India) Pvt Ltd', 'quantity': '16 Ton', 'price': '19200.00', 'currency': 'INR'}, {'slno': 8, 'description': 'UPS SCS (India) Pvt Ltd', 'quantity': '16 Ton', 'price': '19200.00', 'currency': 'INR'}], 'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0}, 'total_charge': 0.0, 'total_discount': 0.0, 'total_amount': 177000.0, 'amount_paid': 0.0, 'amount_due': 0.0, 'page_no': 1}, {'invoice_number': '20212500', 'invoice_date': '3/23/2021 12:00:00 AM', 'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED', 'gst_no': '33AAT5065J1Z7', 'pan_no': 'Not Available', 'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Ambattur Industrial Estate, Chennai 600 058', 'phone_number': '+91-7550015666,8939601566', 'email': 'support@freightx.in'}, 'buyer_details': {'name': 'Ms. SHARADAA CERAMICS PRIVATE LIMITED DP', 'gst_no': 'Not Available', 'pan_no': 'Not Available', 'address': '39 4B 5B KAKKALUR INDUSTRIAL ESTATE KAKKALUR THIRUVALLUR-602003', 'phone_number': 'Not Available', 'email': 'Not Available'}, 'items': [{'slno': 1, 'description': 'SB NO 96083 40/24.03.21 CNTR NO. FCIU4299693', 'quantity': 'Not Available', 'price': 'Not Available', 'currency': 'INR'}], 'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0}, 'total_charge': 0.0, 'total_discount': 0.0, 'total_amount': 0.0, 'amount_paid': 0.0, 'amount_due': 0.0, 'page_no': 2}, {'invoice_number': '20-21/2500', 'invoice_date': '23-3-2021', 'seller_details': {'name': 'TRANSITECH PRIVATE LIMITED', 'gst_no': '33AAFCT5065J1Z7', 'pan_no': 'Not Available', 'address': 'Plot No. 18-20, Ambit Park Road, Ambattur Industrial Estate, Chennai 600 058', 'phone_number': '7550015666 / 8939601566', 'email': 'support@freightx.in'}, 'buyer_details': {'name': 'UPS SCS (INDIA) PVT LTD', 'gst_no': '33AAACU2488B1ZN', 'pan_no': 'Not Available', 'address': 'No. 3/26, 10th Avenue, Ashok Nagar, Chennai', 'phone_number': 'Not Available', 'email': 'Not Available'}, 'items': [{'slno': 1, 'description': 'Your Freight Driver was Sathish', 'quantity': '1', 'price': '17000.00', 'currency': 'INR'}, {'slno': 2, 'description': 'Total Distance 500 Km', 'quantity': '1', 'price': '10000.00', 'currency': 'INR'}, {'slno': 3, 'description': 'Waiting Minutes 0 mins', 'quantity': '1', 'price': '0.00', 'currency': 'INR'}, {'slno': 4, 'description': 'Total Trip Time 0', 'quantity': '1', 'price': '0.00', 'currency': 'INR'}, {'slno': 5, 'description': 'Distance Fare', 'quantity': '1', 'price': '17000.00', 'currency': 'INR'}, {'slno': 6, 'description': 'Halting Charges', 'quantity': '1', 'price': '10000.00', 'currency': 'INR'}, {'slno': 7, 'descri ...

# %%
len(data["details"])
# Out:
# 35

# %%
data["details"][17]
# Out:
# {'invoice_number': '9608540',
#  'invoice_date': '27/03/2021',
#  'seller_details': {'name': 'AALCMIORSECHBBI TRANSOREIN LOGISTICS SERVICES PVT LTD',
#   'gst_no': 'Not Available',
#   'pan_no': 'Not Available',
#   'address': 'CHENNAI - 600001',
#   'phone_number': 'Not Available',
#   'email': 'Not Available'},
#  'buyer_details': {'name': 'Not Available',
#   'gst_no': 'Not Available',
#   'pan_no': 'Not Available',
#   'address': 'Not Available',
#   'phone_number': 'Not Available',
#   'email': 'Not Available'},
#  'items': [{'slno': 1,
#    'description': 'RITC',
#    'quantity': '1.00',
#    'price': '78000.00',
#    'currency': 'INR'},
#   {'slno': 2,
#    'description': 'SINGLE WINDOW INFO TYPE DETAILS',
#    'quantity': '1.00',
#    'price': '12985.00',
#    'currency': 'INR'}],
#  'total_tax': {'CGST': 0.0, 'SGST': 0.0, 'IGST': 0.0},
#  'total_charge': 0.0,
#  'total_discount': 0.0,
#  'total_amount': 33760.0,
#  'amount_paid': 0.0,
#  'amount_due': 0.0,
#  'page_no': 18}
